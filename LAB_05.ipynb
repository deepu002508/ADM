# %% [markdown]
# <a href="https://colab.research.google.com/github/deepu002508/ADM/blob/main/LAB_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'City': ['New York', 'New York', 'Los Angeles', 'Los Angeles', 'Chicago', 'Chicago'],
    'Product Category': ['Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing'],
    'Sales': [1000, 500, 1500, 700, 800, 600]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#           City Product Category  Sales
# 0     New York      Electronics   1000
# 1     New York         Clothing    500
# 2  Los Angeles      Electronics   1500
# 3  Los Angeles         Clothing    700
# 4      Chicago      Electronics    800
# 5      Chicago         Clothing    600
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('City').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Product Category').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Product Category'].value_counts()
#     for x_label, grp in df.groupby('City')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('City')
# _ = plt.ylabel('Product Category')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['City'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Sales', y='City', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Product Category'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Sales', y='Product Category', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
city_sales = df.groupby('City')['Sales'].sum()
print(city_sales)
# Out:
# City
# Chicago        1400
# Los Angeles    2200
# New York       1500
# Name: Sales, dtype: int64

# %%
city_sales = df.groupby('City')['Sales'].max()
print(city_sales)
# Out:
# City
# Chicago         800
# Los Angeles    1500
# New York       1000
# Name: Sales, dtype: int64

# %%
city_sales = df.groupby('City')['Sales'].mean()
print(city_sales)
# Out:
# City
# Chicago         700.0
# Los Angeles    1100.0
# New York        750.0
# Name: Sales, dtype: float64

# %%
city_sales = df.groupby('City')['Sales'].max()
print(city_sales)
# Out:
# City
# Chicago         800
# Los Angeles    1500
# New York       1000
# Name: Sales, dtype: int64

# %% [markdown]
# When to Use?
#
# Use groupby when you want to summarize data by one or more categories.
#
# Use pivot_table when you want to reshape the data for better readability and comparison

# %% [markdown]
# Explanation of Each Parameter:
#
# Parameter	Description
#
# values='Sales'	Specifies the column whose values will be aggregated (in this case, Sales).
#
# index='City'	Defines the row labels (index), grouping the data by City.
#
# columns='Product Category'	Defines the column labels, categorizing sales by product type.
#
# aggfunc='mean'	Specifies the aggregation function (here, mean), calculating the average sales per category per city.
#
# fill_value=0	Replaces any missing values (NaN) with 0, ensuring a clean table without empty cells.

# %%
pivot_sales = df.pivot_table(values='Sales', index='City', columns='Product Category', aggfunc='mean', fill_value=0)

# %%
print(pivot_sales)
# Out:
# Product Category  Clothing  Electronics
# City
# Chicago              600.0        800.0
# Los Angeles          700.0       1500.0
# New York             500.0       1000.0

# %% [markdown]
# **Pandas Profiling: Generating an EDA**
